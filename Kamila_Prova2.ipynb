# %% [markdown]
# Professor Bruno Pimentel
#
# Kamila de Almeida Benevides
#
#
# ---

# %% [markdown]
# **1) Quais tipos de problemas são preferíveis utilizar Naive Bayes?**
#
# R: Quando se tem um conjunto pequeno de dados para realizar a classificação. Além de classificação de textos, filtragem de SPAM e análise de sentimentos em texto.

# %% [markdown]
# **2) Crie um conjunto de dados com 2 classes para mostrar:**
#
# **a) Uma classificação após usar Árvore de Decisão.**
#
# **b) Uma regra gerada pela árvore (use pelo menos 2 atributos).**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# R-a: Os indivíduos com ID 3, 4 e 6 possuem o IMC normal, já os com ID 1, 2, 5, 7 e 8 possuem alguma alteração.
#
# R-b: Se o indivíduo for feminino, e peso for < 36.3, está abaixo do peso.

# %% [markdown]
# **3) Com relação aos métodos Rede Neural de Camada Única (Perceptron) e
# Máquina de Vetores de Suporte (SVM), descreva:**
#
# **a) Que tipos de problemas eles podem resolver em comum.**
#
# R: Reconhecimento de padrões, classificação de padrões, como texto e imagens.
#
# **b) A principal vantagem do SVM sobre o Perceptron (exemplifique).**
#
# R: Com a máquina de vetores se suporte, com kernel trick é possível separar as classes de forma mais exata, onde no Perceptron não seria possível.

# %% [markdown]
# **4) De que forma modelos para Séries Temporias podem ajudar na descoberta de informação?**
#
# R: Análise de dados utilizando séries temporáis são útil para predizer informações baseados na observação das dos dados ao longo de um período de tempo delimitado. Utilizando uma modelagem matematica é possível compreender o mecanismo da série, possibilitando compreender as razões para o comportamento da série, ou até controlar a trajetória da série.

# %% [markdown]
# **5) Descreva como a Visualização de Dados pode ajudar o cientista de dados.**
#
# R: Demonstrar visualmente o significado dos dados, ajuda chegar em uma boa análise e uma boa comunicação dos dados como informar, entender e tomar uma decisão.
